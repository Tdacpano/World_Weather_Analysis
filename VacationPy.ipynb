# %%
# Import the required libraries
import hvplot.pandas
import pandas as pd
from config import geoapify_key
# Import the required libraries
import requests

# %%
# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID           City Country                 Date      Lat       Lng  \
# 0        0       Yar-Sale      RU  2022-12-21 17:41:24  66.8333   70.8333
# 1        1          Vaini      TO  2022-12-21 17:41:25 -21.2000 -175.2000
# 2        2  Makakilo City      US  2022-12-21 17:41:26  21.3469 -158.0858
# 3        3      Cape Town      ZA  2022-12-21 17:40:18 -33.9258   18.4232
# 4        4    Port Alfred      ZA  2022-12-21 17:41:28 -33.5906   26.8910
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     -9.62        95          86        8.30
# 1     73.56       100          40        2.30
# 2     68.99        84          75        6.91
# 3     77.41        59           0        8.05
# 4     70.18        75          56        5.99

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure the map plot_1
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700, 
    frame_height = 500
)

# %%
#display the map plot_1
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]

# %%
# Configure the map plot_2
map_plot_2 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %%
# Configure the map plot_4
map_plot_4 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_4
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %%
# Configure the map plot_2
map_plot_2 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriTerrain",
    frame_width = 500,
    frame_height = 200,
    size = "Wind Speed",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Wind Speed)

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 90

# %%
preferred_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)
]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date      Lat       Lng  \
# 1         1           Vaini      TO  2022-12-21 17:41:25 -21.2000 -175.2000
# 3         3       Cape Town      ZA  2022-12-21 17:40:18 -33.9258   18.4232
# 4         4     Port Alfred      ZA  2022-12-21 17:41:28 -33.5906   26.8910
# 6         6            Luba      GQ  2022-12-21 17:41:29   3.4568    8.5547
# 8         8          Matadi      CD  2022-12-21 17:41:30  -5.8167   13.4500
# 10       10        Saldanha      ZA  2022-12-21 17:41:31 -33.0117   17.9442
# 13       13        Hermanus      ZA  2022-12-21 17:41:32 -34.4187   19.2345
# 19       19  Saint-Philippe      RE  2022-12-21 17:41:35 -21.3585   55.7679
# 20       20      Butaritari      KI  2022-12-21 17:41:36   3.0707  172.7902
# 21       21    Jacareacanga      BR  2022-12-21 17:41:36  -6.2222  -57.7528
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 1      73.56       100          40        2.30
# 3      77.41        59           0        8.05
# 4      70.18        75          56        5.99
# 6      80.33        79          92        7.05
# 8      79.48        76          58        4.23
# 10     87.85        69          17       11.36
# 13     72.81        67           0       11.34
# 19     78.39        77          94        8.25
# 20     81.61        74          46       18.61
# 21     83.21        77          70        3.69

# %%
preferred_cities_df.count()
# Out:
# City_ID       163
# City          163
# Country       162
# Date          163
# Lat           163
# Lng           163
# Max Temp      163
# Humidity      163
# Cloudiness    163
# Wind Speed    163
# dtype: int64

# %%
preferred_cities_df.isnull().sum()
# Out:
# City_ID       0
# City          0
# Country       1
# Date          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# dtype: int64

# %%
preferred_cities_df_2= preferred_cities_df.dropna()

# %%
preferred_cities_df_2.count()
# Out:
# City_ID       162
# City          162
# Country       162
# Date          162
# Lat           162
# Lng           162
# Max Temp      162
# Humidity      162
# Cloudiness    162
# Wind Speed    162
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp      Lat       Lng Hotel Name
# 1            Vaini      TO     73.56 -21.2000 -175.2000
# 3        Cape Town      ZA     77.41 -33.9258   18.4232
# 4      Port Alfred      ZA     70.18 -33.5906   26.8910
# 6             Luba      GQ     80.33   3.4568    8.5547
# 8           Matadi      CD     79.48  -5.8167   13.4500
# 10        Saldanha      ZA     87.85 -33.0117   17.9442
# 13        Hermanus      ZA     72.81 -34.4187   19.2345
# 19  Saint-Philippe      RE     78.39 -21.3585   55.7679
# 20      Butaritari      KI     81.61   3.0707  172.7902
# 21    Jacareacanga      BR     83.21  -6.2222  -57.7528

# %%
# Set initial parameters to search for a hotel.
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
}

# %%
# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"

    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()
    # Get the first hotel from the results and store the name
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
    # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

# %%
# Configure the map
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map plot
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country)
